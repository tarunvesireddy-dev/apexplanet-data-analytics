# %%
df=pd.read_csv('data/Sample - Superstore.csv')
df=pd.read-excel('data/Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3556366135.py in <module>
# ----> 1 df=pd.read_csv('data/Sample - Superstore.csv')
#       2 df=pd.read-excel('data/Sample - Superstore.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df=pd.read_csv('data/Sample - Superstore.csv')
df=pd.read-excel('data/Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/2332790277.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('data/Sample - Superstore.csv')
#       3 df=pd.read-excel('data/Sample - Superstore.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
df.head()
df.shape
df.info()
df.describe()
df.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/1152421969.py in <module>
# ----> 1 df.head()
#       2 df.shape
#       3 df.info()
#       4 df.describe()
#       5 df.columns.tolist()
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('data/Sample - Superstore.csv')
df=pd.read-excel('data/Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3556366135.py in <module>
# ----> 1 df=pd.read_csv('data/Sample - Superstore.csv')
#       2 df=pd.read-excel('data/Sample - Superstore.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import os
print(os.getcwd())os.listdir(r'C:\Users\Jaya\Downloads')
print(os.listdir())os.listdir(r'C:\Users\Jaya\Downloads')
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb']

# %%
os.listdir(r'C:\Users\Jaya\Downloads')
# Out:
# ['(2026) SE-3 UNITS NOTES.pdf',
#  '13C_MAJOR_PROJECT_TELUGU_NEWS_CLASSIFICATION_ROLL_Y.docx',
#  '1da314ab-0ff6-4835-bc92-e92e1916ffbb.pdf',
#  '3-1-CN-LAB-MANUAL-AIDS.pdf',
#  '3rd ,4th ,5th UNITS (DM).pdf',
#  '8a1de1cb-a8f9-43bb-bd9e-d415a64e999f.docx',
#  'Aadhar Card.pdf',
#  'BEFA - Question Bank (Reg - 22) UPDATED LATEST (1).docx',
#  'BEFA - Question Bank (Reg - 22) UPDATED LATEST.docx',
#  'BEFA answers.pdf',
#  'BEFA Complete Notes.docx',
#  'BEFA mid 1 imp.docx',
#  'BEFA set 1 Imp.pdf',
#  'BEFA set 2...Imp.pdf',
#  'CANIXA CRS PARTY WISE SALES SEPT 2025.txt',
#  'CERTIFICATION_Certified_Pega_System_Architect.pdf',
#  'CH20B027_YASHASWI SAGAR.P_RESUME (4).pdf',
#  'ChromeSetup.exe',
#  'Claude Setup.exe',
#  'dbbcfcc2-7730-4aba-9c18-548e3bf470e9.docx',
#  'DBMS UNIT 2 .pdf',
#  'desktop.ini',
#  'DIS MATHS 2-2 (1).docx',
#  'dm mid 2 set 1 ans.pdf',
#  'DM SET-1.pdf',
#  'DM SET-2 Q&A.pdf',
#  'DM SET-II.pdf',
#  'Dm U-2.pdf',
#  'dm unit--1,2.pdf',
# ...

# %%
import pandas as pd

# path is relative to where your notebook lives
df = pd.read_csv("../data/superstore.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/1528817749.py in <module>
#       2
#       3 # path is relative to where your notebook lives
# ----> 4 df = pd.read_csv("../data/superstore.csv")
#       5
#       6 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks

# %%
os.listdir("../data")
# Out:
# ['Sample - Superstore.csv', 'Sample - Superstore.csv.zip']

# %%
df = pd.read_csv("../data/Sample - Superstore.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11468/3055992789.py in <module>
# ----> 1 df = pd.read_csv("../data/Sample - Superstore.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import os
path = "../data/Sample - Superstore.csv"
print(os.path.isfile(path))   # True if it's a real file
print(os.path.isdir(path))    # True if it's actually a folder
# Out:
# False
# True

# %%
import os
print(os.listdir("../data/Sample - Superstore.csv"))
# Out:
# ['Sample - Superstore.csv']

# %%
df = pd.read_csv("../data/Sample - Superstore.csv/Sample - Superstore.csv", encoding="latin1")

# %%
df = pd.read_csv("../data/Sample - Superstore.csv/Sample - Superstore.csv", encoding="latin1")
df.shape
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape          # rows/columns count
df.info()         # data types + null counts
df.isnull().sum() # nulls per column
df.duplicated().sum()  # duplicate rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.info()  # confirm they're now datetime64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby('Category')['Sales'].sum().sort_values().plot(kind='barh', figsize=(8,4))
plt.title('Total Sales by Category')
plt.xlabel('Sales')
plt.tight_layout()
plt.show()

# %%
df.groupby('Category')['Discount'].mean()
# Out:
# Category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(df['Discount'], df['Profit'], alpha=0.3)
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Discount vs Profit')
plt.axhline(0, color='red', linestyle='--')  # zero-profit line
plt.show()

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values()
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
df[df['Sub-Category']=='Tables'][['Discount','Profit']].describe()
# Out:
#          Discount       Profit
# count  319.000000   319.000000
# mean     0.261285   -55.565771
# std      0.169622   230.565006
# min      0.000000 -1862.312400
# 25%      0.200000  -122.829300
# 50%      0.300000   -31.372200
# 75%      0.400000    33.851700
# max      0.500000   629.010000

# %%
df.to_csv('../data/superstore_cleaned.csv', index=False)

# %%
import os
os.path.exists('../data/superstore_cleaned.csv')
# Out:
# True

# %%
check = pd.read_csv('../data/superstore_cleaned.csv')
check.shape  # should show (9994, 21)
# Out:
# (9994, 21)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks
