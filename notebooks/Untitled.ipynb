# %%
import os
print(os.get cwd())
print(os.listdir())
# Out:
#   File "C:\Users\Jaya\AppData\Local\Temp/ipykernel_24452/32272202.py", line 2
#     print(os.get cwd())
#                  ^
# SyntaxError: invalid syntax

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
import pandas as pd

# %%
df=pd.read_csv('data/Sample - Superstore.csv')
df=pd.read-excel('data/Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24452/174265663.py in <module>
# ----> 1 df=pd.read_csv('data/Sample - Superstore.csv')
#       2 df=pd.read-excel('data/Sample - Superstore.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Jaya\Desktop\apexplanet-data-analytics\notebooks

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %%
import glob
glob.glob('**/Sample*.csv', recursive=True)
# Out:
# []

# %%
df = pd.read_excel('data/Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24452/1499901851.py in <module>
# ----> 1 df = pd.read_excel('data/Sample - Superstore.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# ...

# %%
df = pd.read_csv(r'C:\Users\Jaya\Desktop\apexplanet-data-analytics\data\Sample - Superstore.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24452/3754471914.py in <module>
# ----> 1 df = pd.read_csv(r'C:\Users\Jaya\Desktop\apexplanet-data-analytics\data\Sample - Superstore.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import glob
glob.glob(r'C:\Users\Jaya\Desktop\**\Sample*.csv', recursive=True)
# Out:
# []

# %%
glob.glob(r'C:\Users\Jaya\**\Sample*.csv', recursive=True)
# Out:
# ['C:\\Users\\Jaya\\anaconda3\\Lib\\site-packages\\astropy\\timeseries\\tests\\data\\sampled.csv',
#  'C:\\Users\\Jaya\\anaconda3\\pkgs\\astropy-4.3.1-py39hc7d831d_0\\Lib\\site-packages\\astropy\\timeseries\\tests\\data\\sampled.csv']

# %%
glob.glob(r'C:\Users\Jaya\Downloads\**\Sample*.csv', recursive=True)
# Out:
# []

# %%
glob.glob(r'C:\Users\Jaya\Downloads\**\Sample*.csv', recursive=True)
# Out:
# []

# %%
import os
   os.listdir(r'C:\Users\Jaya\Downloads')
# Out:
#   File "C:\Users\Jaya\AppData\Local\Temp/ipykernel_24452/4266942460.py", line 2
#     os.listdir(r'C:\Users\Jaya\Downloads')
#     ^
# IndentationError: unexpected indent
